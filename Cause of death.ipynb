# %%
#import various libraries
import pandas as pd    
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
#display maximum columns and rows
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
#load the data and display top 10 datas
df=pd.read_excel(r"C:\Users\91980\OneDrive\Desktop\cause_of_deaths dataset.xlsx")
df.head(10)
# Out:
#   Country/Territory Code  Year  Meningitis  \
# 0       Afghanistan  AFG  1990        2159
# 1       Afghanistan  AFG  1991        2218
# 2       Afghanistan  AFG  1992        2475
# 3       Afghanistan  AFG  1993        2812
# 4       Afghanistan  AFG  1994        3027
# 5       Afghanistan  AFG  1995        3102
# 6       Afghanistan  AFG  1996        3193
# 7       Afghanistan  AFG  1997        3304
# 8       Afghanistan  AFG  1998        3281
# 9       Afghanistan  AFG  1999        3200
#
#    Alzheimer's Disease and Other Dementias  Parkinson's Disease  \
# 0                                     1116                  371
# 1                                     1136                  374
# 2                                     1162                  378
# 3                                     1187                  384
# 4                                     1211                  391
# 5                                     1225                  394
# ...

# %%
#No. of rows and columns
df.shape
# Out:
# (6120, 34)

# %%
#name of the columns
df.columns
# Out:
# Index(['Country/Territory', 'Code', 'Year', 'Meningitis',
#        'Alzheimer's Disease and Other Dementias', 'Parkinson's Disease',
#        'Nutritional Deficiencies', 'Malaria', 'Drowning',
#        'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
#        'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
#        'Lower Respiratory Infections', 'Neonatal Disorders',
#        'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
#        'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
#        'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
#        'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
#        'Road Injuries', 'Chronic Respiratory Diseases',
#        'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
#        'Fire, Heat, and Hot Substances', 'Acute Hepatitis'],
#       dtype='object')

# %%
#datatypes
df.dtypes
# Out:
# Country/Territory                             object
# Code                                          object
# Year                                           int64
# Meningitis                                     int64
# Alzheimer's Disease and Other Dementias        int64
# Parkinson's Disease                            int64
# Nutritional Deficiencies                       int64
# Malaria                                        int64
# Drowning                                       int64
# Interpersonal Violence                         int64
# Maternal Disorders                             int64
# HIV/AIDS                                       int64
# Drug Use Disorders                             int64
# Tuberculosis                                   int64
# Cardiovascular Diseases                        int64
# Lower Respiratory Infections                   int64
# Neonatal Disorders                             int64
# Alcohol Use Disorders                          int64
# ...

# %%
df.isnull().sum().sum()
#there is no null values in this dataset
# Out:
# 0

# %%
#statistical summary
df.describe()
# Out:
#               Year    Meningitis  Alzheimer's Disease and Other Dementias  \
# count  6120.000000   6120.000000                              6120.000000
# mean   2004.500000   1719.701307                              4864.189379
# std       8.656149   6672.006930                             18220.659072
# min    1990.000000      0.000000                                 0.000000
# 25%    1997.000000     15.000000                                90.000000
# 50%    2004.500000    109.000000                               666.500000
# 75%    2012.000000    847.250000                              2456.250000
# max    2019.000000  98358.000000                            320715.000000
#
#        Parkinson's Disease  Nutritional Deficiencies        Malaria  \
# count          6120.000000               6120.000000    6120.000000
# mean           1173.169118               2253.600000    4140.960131
# std            4616.156238              10483.633601   18427.753137
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6120 entries, 0 to 6119
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country/Territory                           6120 non-null   object
#  1   Code                                        6120 non-null   object
#  2   Year                                        6120 non-null   int64
#  3   Meningitis                                  6120 non-null   int64
#  4   Alzheimer's Disease and Other Dementias     6120 non-null   int64
#  5   Parkinson's Disease                         6120 non-null   int64
#  6   Nutritional Deficiencies                    6120 non-null   int64
#  7   Malaria                                     6120 non-null   int64
#  8   Drowning                                    6120 non-null   int64
#  9   Interpersonal Violence                      6120 non-null   int64
# ...

# %% [markdown]
# # EDA

# %%
#unique values of column year
df['Year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
#no. of unique values of column year
df['Year'].nunique()
# Out:
# 30

# %%
#no. of unique data in column country/territory
df['Country/Territory'].nunique()
# Out:
# 204

# %%
#make a list of cause of deaths 
cause_of_deaths=['Meningitis', 'Alzheimer\'s Disease and Other Dementias',
       'Parkinson\'s Disease', 'Nutritional Deficiencies', 'Malaria',
       'Drowning', 'Interpersonal Violence', 'Maternal Disorders', 'HIV/AIDS',
       'Drug Use Disorders', 'Tuberculosis', 'Cardiovascular Diseases',
       'Lower Respiratory Infections', 'Neonatal Disorders',
       'Alcohol Use Disorders', 'Self-harm', 'Exposure to Forces of Nature',
       'Diarrheal Diseases', 'Environmental Heat and Cold Exposure',
       'Neoplasms', 'Conflict and Terrorism', 'Diabetes Mellitus',
       'Chronic Kidney Disease', 'Poisonings', 'Protein-Energy Malnutrition',
       'Road Injuries', 'Chronic Respiratory Diseases',
       'Cirrhosis and Other Chronic Liver Diseases', 'Digestive Diseases',
       'Fire, Heat, and Hot Substances', 'Acute Hepatitis']

# %%
# summation of cause of deaths data
df['Total_Deaths'] = df[cause_of_deaths].sum(axis=1)

# %%
# top 50 maximum deaths with respect to country
maximum_deaths = df.sort_values(by='Total_Deaths',ascending=False)[:50][['Total_Deaths','Country/Territory']]
maximum_deaths
# Out:
#       Total_Deaths Country/Territory
# 1139      10442561             China
# 1138      10163943             China
# 1137       9978653             China
# 1119       9814213             China
# 1118       9591222             China
# 1117       9503904             China
# 1116       9411928             China
# 1114       9366974             China
# 1115       9364587             China
# 1113       9284664             China
# 1112       9074833             China
# 1135       8982702             China
# 1111       8972670             China
# 1134       8960684             China
# 2459       8812747             India
# 1136       8794396             China
# 1110       8755201             China
# 1133       8750361             China
# 2458       8698039             India
# 1132       8610956             China
# 1131       8490928             China
# 2457       8471931             India
# 1130       8404159             China
# 2435       8394566             India
# ...

# %% [markdown]
# It shows maximum no. of deaths in China and India

# %%
#Total causes of death in countries without year mentioning
countries_total_deaths_df = df.groupby('Country/Territory').sum()
countries_total_deaths_df.drop('Year',axis=1,inplace=True)

# %%
# Top 5 Countries total no. of deaths with from year 1990-2019
countries_total_deaths_df.sort_values(by='Total_Deaths',ascending =False)[:5]
# Out:
#                    Meningitis  Alzheimer's Disease and Other Dementias  \
# Country/Territory
# China                  480899                                  5381846
# India                 2008944                                  1707561
# United States           40032                                  3302609
# Russia                  60519                                   972305
# Indonesia              337724                                   487566
#
#                    Parkinson's Disease  Nutritional Deficiencies  Malaria  \
# Country/Territory
# China                          1533092                    584236    13418
# India                           756832                   3290569  2439244
# United States                   661288                    133044        0
# Russia                          236367                     15906        0
# Indonesia                       145752                    604467    74664
#
# ...

# %% [markdown]
# # China

# %% [markdown]
# Total Deaths in China from year 1990-2019: 265408106
#
# FIND OUT:
#     -total number of deaths in china year-wise
#     - main cause of death in china and their trends year-wise

# %%
#total deaths w.r.t year with cause _of_deaths data
china_total_deaths_df = df[df['Country/Territory']=='China'].sort_values(by='Total_Deaths',ascending=False)

# %%
#plot a death trends in china from year 1990 to 2019
plt.figure(figsize=(10,5))
sns.scatterplot(x='Year', y='Total_Deaths',data=china_total_deaths_df)
plt.xlabel("Year")
plt.ylabel("Total no.of Deaths")
plt.title("Year Vs. Total no.of Deaths in China")
plt.show()

# %% [markdown]
# This shows death rate of china is increases from year 1990 to 2019

# %%
china= countries_total_deaths_df.sort_values(by='Total_Deaths',ascending =False)[:1]
china
# Out:
#                    Meningitis  Alzheimer's Disease and Other Dementias  \
# Country/Territory
# China                  480899                                  5381846
#
#                    Parkinson's Disease  Nutritional Deficiencies  Malaria  \
# Country/Territory
# China                          1533092                    584236    13418
#
#                    Drowning  Interpersonal Violence  Maternal Disorders  \
# Country/Territory
# China               2873619                  776275              243257
#
#                    HIV/AIDS  Drug Use Disorders  Tuberculosis  \
# Country/Territory
# China                433709              626914       2708461
#
#                    Cardiovascular Diseases  Lower Respiratory Infections  \
# Country/Territory
# China                            100505973                       8525819
#
#                    Neonatal Disorders  Alcohol Use Disorders  Self-harm  \
# Country/Territory
# ...

# %%
#top 10 main cause of death in china with maximum deaths
china.iloc[0].sort_values(ascending=False)[1:11]
# Out:
# Cardiovascular Diseases                       100505973
# Neoplasms                                      61060527
# Chronic Respiratory Diseases                   36676826
# Digestive Diseases                              8924906
# Lower Respiratory Infections                    8525819
# Road Injuries                                   8350399
# Alzheimer's Disease and Other Dementias         5381846
# Self-harm                                       5078550
# Cirrhosis and Other Chronic Liver Diseases      4918899
# Neonatal Disorders                              4353666
# Name: China, dtype: int64

# %%
#plot the bar graph of top 10 main cause of deaths in china from year 1990-2019
plt.figure(figsize=(15,5))
china.iloc[0].sort_values(ascending=False)[1:11].plot(kind='barh')
plt.xlabel("Total no.of Deaths")
plt.ylabel("Causes of Deaths")
plt.title("Top 10 Causes of Deaths in China")
plt.show()

# %%
#plot a graph of year vs deaths due to cardiovascular diseases in china 
plt.figure(figsize=(15,3))
china_df = china_total_deaths_df.groupby(['Country/Territory','Year']).sum()
china_df['Cardiovascular Diseases'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Cardiovascular Diseases in china")
plt.show()

# %% [markdown]
# Deaths due to Cardiovascular Diseases in china are increases fom year 1990 to 2019

# %%
#plot a graph of Year Vs. Deaths due to Neoplasms in china
plt.figure(figsize=(15,3))
china_df = china_total_deaths_df.groupby(['Country/Territory','Year']).sum()
china_df['Neoplasms'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Neoplasms in china")
plt.show()

# %% [markdown]
# Deaths due to Neoplasms in china are increases rapidly from 1990 to 2019

# %%
#plot a graph of Year Vs. Deaths due to Chronic Respiratory Diseases in china
plt.figure(figsize=(15,3))
china_df = china_total_deaths_df.groupby(['Country/Territory','Year']).sum()
china_df['Chronic Respiratory Diseases'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Chronic Respiratory Diseases in china")
plt.show()

# %% [markdown]
#  Deaths due to Chronic Respiratory Diseases in china are approax. constant throughout the year with high number of deaths

# %%
#plot a graph of Year Vs. Deaths due to Digestive Diseases in china
plt.figure(figsize=(15,3))
china_df = china_total_deaths_df.groupby(['Country/Territory','Year']).sum()
china_df['Digestive Diseases'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Digestive Diseases in china")
plt.show()

# %% [markdown]
# Deaths due to Digestive Diseases in china are approax. constant throughout the year with maximum deaths.

# %%
# plot a graph of Year Vs. Deaths due to Lower Respiratory Infections in china
plt.figure(figsize=(15,3))
china_df = china_total_deaths_df.groupby(['Country/Territory','Year']).sum()
china_df['Lower Respiratory Infections'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Lower Respiratory Infections in china")
plt.show()

# %% [markdown]
#  Deaths due to Lower Respiratory Infections in china are decreases from 1990 to 2019

# %% [markdown]
# # INDIA

# %% [markdown]
# Total Deaths in India from year 1990-2019: 238158165
#
# FIND OUT:
#     -total number of deaths in India year-wise
#     - main cause of death in India and their trends year-wise

# %%
#total deaths w.r.t year with cause _of_deaths data
India_total_deaths_df = df[df['Country/Territory']=='India'].sort_values(by='Total_Deaths',ascending=False)

# %%
#plot a graph year vs total no. of deaths in India
plt.figure(figsize=(10,5))
sns.scatterplot(x='Year', y='Total_Deaths',data=India_total_deaths_df)
plt.xlabel("Year")
plt.ylabel("Total no.of Deaths")
plt.title("Year Vs. Total no.of Deaths in India")
plt.show()

# %%
#showing india data 
India= countries_total_deaths_df.sort_values(by='Total_Deaths',ascending =False)[1:2]
India
# Out:
#                    Meningitis  Alzheimer's Disease and Other Dementias  \
# Country/Territory
# India                 2008944                                  1707561
#
#                    Parkinson's Disease  Nutritional Deficiencies  Malaria  \
# Country/Territory
# India                           756832                   3290569  2439244
#
#                    Drowning  Interpersonal Violence  Maternal Disorders  \
# Country/Territory
# India               2110438                 1237163             2292449
#
#                    HIV/AIDS  Drug Use Disorders  Tuberculosis  \
# Country/Territory
# India               2454374              168928      15820922
#
#                    Cardiovascular Diseases  Lower Respiratory Infections  \
# Country/Territory
# India                             52994710                      16419404
#
#                    Neonatal Disorders  Alcohol Use Disorders  Self-harm  \
# Country/Territory
# ...

# %%
#top 10 main cause of death in India with maximum deaths
India.iloc[0].sort_values(ascending=False)[1:11]
# Out:
# Cardiovascular Diseases                       52994710
# Diarrheal Diseases                            26243547
# Chronic Respiratory Diseases                  25232974
# Neonatal Disorders                            20911570
# Neoplasms                                     17762703
# Lower Respiratory Infections                  16419404
# Tuberculosis                                  15820922
# Digestive Diseases                            11804380
# Cirrhosis and Other Chronic Liver Diseases     6294910
# Self-harm                                      5543395
# Name: India, dtype: int64

# %%
# plot a graph of top 10 main cause of deaths in india
plt.figure(figsize=(15,5))
India.iloc[0].sort_values(ascending=False)[1:11].plot(kind='barh')
plt.xlabel("Total no.of Deaths")
plt.ylabel("Causes of Deaths")
plt.title("Top 10 Main Causes of Deaths in India")
plt.show()

# %%
#plot a graph of Year Vs. Deaths due to Cardiovascular Diseases in India
plt.figure(figsize=(15,3))
India_df = India_total_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Cardiovascular Diseases'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Cardiovascular Diseases in India")
plt.show()

# %% [markdown]
# Deaths due to Cardiovascular Diseases in India are increases rapidly from 1990 to 2019

# %%
#plot a graph of Year Vs. Deaths due to Diarrheal Diseases in India
plt.figure(figsize=(15,3))
India_df = India_total_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Diarrheal Diseases'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Diarrheal Diseases in India")
plt.show()

# %% [markdown]
#  Deaths due to Diarrheal Diseases in India are decreases very slowly from 1990 to 2019

# %%
# plot a graph of Year Vs. Deaths due to Chronic Respiratory Diseases in India
plt.figure(figsize=(15,3))
India_df = India_total_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Chronic Respiratory Diseases'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Chronic Respiratory Diseases in India")
plt.show()

# %% [markdown]
# Deaths due to Chronic Respiratory Diseases in India are increases from 1990 to 2019

# %%
# plot a graph of Year Vs. Deaths due to Neonatal Disorders in India
plt.figure(figsize=(15,3))
India_df = India_total_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Neonatal Disorders'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Neonatal Disorders in India")
plt.show()

# %% [markdown]
# Deaths due to Neonatal Disorders in India are decreases very slowly from 1990 to 2019

# %%
# plot a graph of Year Vs. Deaths due to Neoplasms in India
plt.figure(figsize=(15,3))
India_df = India_total_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Neoplasms'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Neoplasms in India")
plt.show()

# %% [markdown]
#  Deaths due to Neoplasms in India are increases from 1990 to 2019

# %%
# plot a graph of Year Vs. Deaths due to Lower Respiratory Infections in India
plt.figure(figsize=(15,3))
India_df = India_total_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Lower Respiratory Infections'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Lower Respiratory Infections in India")
plt.show()

# %% [markdown]
#  Deaths due to Lower Respiratory Infections in India are decreases very slowly from 1990 to 2019

# %%
# plot a graph of Year Vs. Deaths due to Tuberculosis in India
plt.figure(figsize=(15,3))
India_df = India_total_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Tuberculosis'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Tuberculosis in India")
plt.show()

# %% [markdown]
# Deaths due to Tuberculosis in India are almost constant throughout the year but small decrease seen after 2000

# %%
# plot a graph of Year Vs. Deaths due to Digestive Diseases in India
plt.figure(figsize=(15,3))
India_df = India_total_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Digestive Diseases'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Digestive Diseases in India")
plt.show()

# %% [markdown]
# Deaths due to Digestive Diseases in India are increasing rapidly from 1990 to 2019

# %%
#plot a graph of Year Vs. Deaths due to Cirrhosis and Other Chronic Liver Diseases in India
plt.figure(figsize=(15,3))
India_df = India_total_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Cirrhosis and Other Chronic Liver Diseases'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Cirrhosis and Other Chronic Liver Diseases in India")
plt.show()

# %% [markdown]
#  Deaths due to Cirrhosis and Other Chronic Liver Diseases in India are increases rapidly from 1990 to 2019

# %%
# plot a graph of Year Vs. Deaths due to Self-harm in India
plt.figure(figsize=(15,3))
India_df = India_total_deaths_df.groupby(['Country/Territory','Year']).sum()
India_df['Self-harm'].plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Deaths")
plt.title("Year Vs. Deaths due to Self-harm in India")
plt.show()

# %% [markdown]
#  Deaths due to Self-harm in India are low in 1990 to 1996 then increases and almost constant from there.

# %% [markdown]
# # Year with Maximum Number of deaths

# %%
#graph to show maximum death in year 
df["Total_Deaths"] = df.iloc[:,3:].sum(axis=1)
deathyear = df.groupby("Year").sum()["Total_Deaths"]
plt.figure(figsize=(9,7))
deathyear.plot(marker="*")
plt.ylabel("Deaths")
# Out:
# Text(0, 0.5, 'Deaths')

# %% [markdown]
# Year 2020 have maximum deaths as per data.

# %% [markdown]
# # Trends of Diseases year wise from 1990-2019

# %%
yearly_counts = df.groupby("Year").sum()
yearly_counts
# Out:
#       Meningitis  Alzheimer's Disease and Other Dementias  \
# Year
# 1990      432253                                   560616
# 1991      428621                                   583166
# 1992      426440                                   605894
# 1993      420836                                   629571
# 1994      413799                                   652176
# 1995      409826                                   674815
# 1996      417259                                   696665
# 1997      400893                                   717342
# 1998      393364                                   738768
# 1999      390136                                   761620
# 2000      385994                                   786615
# 2001      379912                                   814526
# 2002      372298                                   845695
# 2003      369171                                   877011
# 2004      363462                                   909148
# ...

# %%
#plt.plot(yearly_counts["Year"],yearly_counts["Meningitis"],data=yearly_counts)

# %%
yearly_counts = df.groupby("Year").sum()
plt.figure(figsize=(30,20))
for i,cause in enumerate(yearly_counts[["Meningitis","Alzheimer\'s Disease and Other Dementias",
                                        "Parkinson's Disease","Nutritional Deficiencies","Malaria","Drowning","Interpersonal Violence",
                                        "Maternal Disorders","HIV/AIDS","Drug Use Disorders","Tuberculosis","Cardiovascular Diseases",
                                        "Lower Respiratory Infections","Neonatal Disorders","Alcohol Use Disorders","Self-harm","Exposure to Forces of Nature",
                                        "Diarrheal Diseases","Environmental Heat and Cold Exposure","Neoplasms"]]):
    plt.subplot(4,5,i+1)
    sns.lineplot(x=yearly_counts.index,y=yearly_counts[cause])
    plt.title(cause,fontweight="bold")
    plt.ylabel("")
    plt.xlabel("")

plt.tight_layout()

# %%
plt.figure(figsize=(30,20))
for i,cause in enumerate(yearly_counts.drop(["Meningitis","Alzheimer\'s Disease and Other Dementias",
                                        "Parkinson's Disease","Nutritional Deficiencies","Malaria","Drowning","Interpersonal Violence",
                                        "Maternal Disorders","HIV/AIDS","Drug Use Disorders","Tuberculosis","Cardiovascular Diseases",
                                        "Lower Respiratory Infections","Neonatal Disorders","Alcohol Use Disorders","Self-harm","Exposure to Forces of Nature",
                                        "Diarrheal Diseases","Environmental Heat and Cold Exposure","Neoplasms" ],axis=1)):
    plt.subplot(5,5,i+1)
    sns.lineplot(x=yearly_counts.index,y=yearly_counts[cause])
    plt.title(cause,fontweight="bold")
    plt.ylabel("")
    plt.xlabel("")

plt.tight_layout()
